# %% [markdown]
# # Jupyter and LIWC Workshop
#
# ## Sonja Sapach

# %%
"We are the BORG " * 10
# Out:
# 'We are the BORG We are the BORG We are the BORG We are the BORG We are the BORG We are the BORG We are the BORG We are the BORG We are the BORG We are the BORG '

# %% [markdown]
# ## LIWC is Linguistic Inquiry and Word Count
#     - Uses a variety of dictionaries and integrated code to help us explore data about psychology/social processes over time.
#     - This will be installed in the lab (as it is an expensive program), but the results can be shared and analyzed.
#     - See below for a link to the website, largely FYI!

# %% [markdown]
# Link to LIWC-22 Website: https://www.liwc.app/

# %% [markdown]
# ### Try it for yourself before the workshop
# #### You can enter a small amount of text (up to 5000 characters) to see a small amount of the type of output LIWC gives...
# Link to LIWC Demo: https://www.liwc.app/demo

# %% [markdown]
# # Jupyter Notebooks
# ### The document you are reading right now was created using the Jupyter Notebook format. I will explain more in the workshop, but for now, note that I have incorporated a brief bit of working Python code, and markup text, and links, in the same space and I am able to share it with you.
#
# While we can use Python (pip) to install just Jupyter Notebooks (or Jupyter Labs), I think it makes more sense to go the "user friendly" route and install the entire Anaconda Distribution - which includes Jupyter Notebooks as well as R Studio and others.
# See the link below, and please install before the workshop if you want to use your own computer.

# %% [markdown]
# Link to Anaconda Distribution Website: https://www.anaconda.com/products/distribution

# %% [markdown]
# # Look, an image as well!
# ## I am sharing this notebook through Github in order to make sure you can access it without knowing anything about Jupyter yet.
#
# If you do not have a personal Github account yet, please make one here: https://github.com/

# %% [markdown]
# ![image.png](attachment:image.png)
