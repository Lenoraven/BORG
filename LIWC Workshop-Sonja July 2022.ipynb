# %% [markdown]
# # LIWC Linguistic Inquiry and Word Count
#
# ## Created by Martha E. Francis and James W. Pennebaker (1996)

# %% [markdown]
# ![6n8uf3.jpg](attachment:6n8uf3.jpg)

# %%
whatIsLIWCQuote = ("The words that people use in everyday life tell us about their psychological states: their beliefs, emotions, thinking habits, lived experiences, social relationships, and personalities. From the time of Freud’s writings about “slips of the tongue” to the early days of computer-based text analysis, researchers across the social sciences have amassed an extensive body of evidence showing that people’s words have tremendous psychological value.")
print(whatIsLIWCQuote)
# Out:
# The words that people use in everyday life tell us about their psychological states: their beliefs, emotions, thinking habits, lived experiences, social relationships, and personalities. From the time of Freud’s writings about “slips of the tongue” to the early days of computer-based text analysis, researchers across the social sciences have amassed an extensive body of evidence showing that people’s words have tremendous psychological value.

# %%
i = 1
LIWC = ("The computer is a great tool, but the interpretation is where the skill lays...I mean lies.")
while i < 6:
  print(LIWC)
  i += 1
# Out:
# The computer is a great tool, but the interpretation is where the skill lays...I mean lies.
# The computer is a great tool, but the interpretation is where the skill lays...I mean lies.
# The computer is a great tool, but the interpretation is where the skill lays...I mean lies.
# The computer is a great tool, but the interpretation is where the skill lays...I mean lies.
# The computer is a great tool, but the interpretation is where the skill lays...I mean lies.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Link to LIWC origin story: https://www.liwc.app/help/psychometrics-manuals

# %% [markdown]
# # Let's look at some analyses!
#
# - Star Trek Scripts: https://www.st-minutiae.com/resources/scripts/
# - Elder Scrolls Online release articles (gathered at the start of my PhD before I changed course....)
# - Interviews we will find at the library!

# %% [markdown]
# ## We can do basic text-mining/NLP stuff here...
# e.g. Word Counts
# ### Finding the word "borg" in my (incomplete) Star Trek script corpus
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Creates wordclouds for us too...
# ![LIWC-22%20Results%20-%20starTrekCorpus%20-%20Word%20Frequencies%20Graph.png](attachment:LIWC-22%20Results%20-%20starTrekCorpus%20-%20Word%20Frequencies%20Graph.png)

# %% [markdown]
# ## Let's look at a straight-forward LIWC analysis of the full Star Trek Script corpus

# %%
import pandas as pd

# %%
data = pd.read_csv('starTrekCorpusLIWCResults.csv')

# %%
data.head()
# Out:
#   Filename  Segment     WC  Analytic  Clout  Authentic   Tone   WPS  BigWords  \
# 0  402.txt        1  21004     77.99  76.21      34.44  20.29  7.41     19.52
# 1  403.txt        1  10113     69.91  75.49      40.83  24.65  7.95     15.18
# 2  404.txt        1   9730     63.37  74.65      30.06  25.54  7.93     18.10
# 3  405.txt        1  10183     75.37  66.71      31.71  22.94  7.42     17.27
# 4  406.txt        1   9227     71.11  70.50      36.69  15.17  7.50     16.17
#
#      Dic  ...  assent  nonflu  filler  AllPunc  Period  Comma  QMark  Exclam  \
# 0  76.61  ...    0.17    0.02     0.0    45.40   28.49   2.84   0.72    0.05
# 1  80.00  ...    0.09    0.04     0.0    43.01   26.57   2.94   0.82    0.07
# 2  76.00  ...    0.20    0.09     0.0    42.93   21.87   3.96   0.96    0.12
# 3  74.45  ...    0.14    0.03     0.0    32.67   15.24   2.74   0.85    0.07
# 4  76.45  ...    0.20    0.18     0.0    46.84   27.21   3.10   0.93    0.11
#
#    Apostro  OtherP
# ...

# %% [markdown]
# ### as you can see, we have a LOT of columns - this is from the standard LIWC dictionary, we can filter!
# I will walk you through some filtering options now...
#
# Wow, wasn't that fun?

# %% [markdown]
# # Ok, yeah, but what does that all mean?
#
# ## I have included 2 documents in the github folder
#
# 1) An older docx discussing analysis of some of the 2015 LIWC variables (the underlying info is relevant still)
#     https://github.com/Lenoraven/BORG/blob/main/interpreting%20LIWC%20results.docx
#
# 2) A longer article written by the creators discussing LIWC in more detail
#     https://github.com/Lenoraven/BORG/blob/main/LIWC%20Article%20Analysis%20Info.pdf
#
# Come back to these when you are working through your own data analysis to refresh your memory!

# %% [markdown]
# ## Evidence - number of articles utilizing various categories
# ### Great information when writing papers arguing that your use of LIWC is methodologically appropriate!
#
# Found as image files on github, or at the end of the above LIWC pdf

# %% [markdown]
# # From here we are going to play with LIWC and talk through interpretations
# ## I have the GDC interviews and have added in a "bonus" to get us thinking.
